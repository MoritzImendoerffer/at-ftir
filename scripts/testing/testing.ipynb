# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_pickle('../../export/one_to_rule_them_all.p')
data.head()
# Out:
#         date            name   3497.0   3495.0   3493.0   3491.0   3489.0  \
# time
# 0     171017  RF Versuch Nr1  0.23281  0.24086  0.24302  0.24436  0.24847
# 1     171017  RF Versuch Nr1  0.23351  0.23452  0.23511  0.24268  0.25079
# 2     171017  RF Versuch Nr1  0.22799  0.24030  0.24846  0.25086  0.25349
# 3     171017  RF Versuch Nr1  0.23041  0.23643  0.24330  0.25101  0.25671
# 4     171017  RF Versuch Nr1  0.22812  0.23541  0.24052  0.24689  0.25268
#
#        3487.0   3485.0   3483.0   ...       766.0    764.0    762.0    760.0  \
# time                              ...
# 0     0.25154  0.25650  0.26662   ...     0.25566  0.25694  0.25856  0.26019
# 1     0.25364  0.25783  0.26642   ...     0.25700  0.25842  0.25996  0.26148
# 2     0.25744  0.25993  0.26349   ...     0.25818  0.25977  0.26140  0.26290
# 3     0.25553  0.25245  0.25720   ...     0.25952  0.26131  0.26310  0.26469
# 4     0.25423  0.25606  0.26169   ...     0.26073  0.26243  0.26426  0.26599
#
# ...

# %%
data.date.unique()
# Out:
# array(['171017', '171018', '171023', '171030', '171113', '171114',
#        '171115', '171121', '171122', '171120', '171116', '171127',
#        '171128', '171129'], dtype=object)

# %%
mask = ['171017','171018','171129']
mask = data.date.isin(mask)

# %%
l = data.iloc[:,3:].loc[mask,:].reset_index().groupby('time').mean()

# %%
for i, item in enumerate(l.iterrows()):
    if i == 3:
        print(item[0])
# Out:
# 100

# %%
l
# Out:
#         3495.0    3493.0    3491.0    3489.0    3487.0    3485.0    3483.0  \
# time
# 0     0.098630  0.102960  0.105237  0.105600  0.104897  0.109653  0.119393
# 1     0.096393  0.097090  0.101053  0.104927  0.107287  0.111793  0.116217
# 10    0.098753  0.102937  0.104130  0.103603  0.102817  0.105127  0.109527
# 100   0.025390  0.025470  0.023900  0.019930  0.016200  0.016960  0.019150
# 101   0.018760  0.019940  0.019520  0.017250  0.016060  0.018640  0.019690
# 102   0.025630  0.023480  0.017340  0.010300  0.006560  0.012500  0.020040
# 103   0.024710  0.024820  0.022950  0.020570  0.018830  0.018880  0.018550
# 104   0.025420  0.027420  0.025160  0.020730  0.018830  0.022460  0.025580
# 105   0.024230  0.022010  0.020980  0.019880  0.020580  0.023400  0.022230
# 106   0.027460  0.024750  0.024200  0.022460  0.017770  0.014570  0.012330
# 107   0.016330  0.020470  0.022170  0.020210  0.017260  0.014960  0.011260
# ...
