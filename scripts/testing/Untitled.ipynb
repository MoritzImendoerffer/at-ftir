# %%
import pandas as pd
from matplotlib import pyplot as plt
import os
# %matplotlib inline

# %%
# get all files in current folder
files = os.listdir('./')

# get all files which end with .p
file = [f for f in files if f.endswith('_raw.p')]

file
# Out:
# ['_raw.p', '171114_raw.p', '171115_raw.p', '171113_raw.p']

# %%
df = pd.read_pickle('171113_raw.p')
data = df.drop(['date', 'name'], axis=1).T

# %%
fig, ax = plt.subplots(ncols=1)
data.plot(cmap=plt.cm.viridis, ax=ax)
ax.legend(['First: dark blue',])

# %%
fig, ax = plt.subplots(ncols=1)
mask = (data.index < 1800) & (data.index>1000)
data.loc[mask,:].plot(cmap=plt.cm.viridis, ax=ax)
ax.legend(['First: dark blue',])
